# %% [markdown]
# <a href="https://colab.research.google.com/github/GugutsTheLegends/arquivos-legais/blob/main/Desafio5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# !pip install plotly

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %%
df = pd.read_csv('/content/data_5.csv' , encoding='latin1')

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1    536365     71053                  WHITE METAL LANTERN       6.0
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
display(df)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1         536365     71053                  WHITE METAL LANTERN       6.0
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS      12.0
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL        6.0
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL        4.0
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE       4.0
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT        3.0
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  535874.000000  535874.000000  403182.000000
# mean        9.587927       4.636533   15287.687868
# std       153.292222      97.302232    1714.009551
# min    -74215.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13952.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     74215.000000   38970.000000   18287.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    535874 non-null  object
#  2   Description  534420 non-null  object
#  3   Quantity     535874 non-null  float64
#  4   InvoiceDate  535874 non-null  object
#  5   UnitPrice    535874 non-null  float64
#  6   CustomerID   403182 non-null  float64
#  7   Country      535874 non-null  object
# dtypes: float64(3), object(5)
# memory usage: 33.1+ MB

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 541904    False
# 541905    False
# 541906    False
# 541907    False
# 541908    False
# Length: 541909, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 5268

# %%
df.duplicated(keep=False).sum()
# Out:
# 10147

# %%
df[df.duplicated(keep=False)]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 485       536409     22111      SCOTTIE DOG HOT WATER BOTTLE       1.0
# 489       536409     22866     HAND WARMER SCOTTY DOG DESIGN       1.0
# 494       536409     21866       UNION JACK FLAG LUGGAGE TAG       1.0
# 517       536409     21866       UNION JACK FLAG LUGGAGE TAG       1.0
# 521       536409     22900   SET 2 TEA TOWELS I LOVE LONDON        1.0
# ...          ...       ...                               ...       ...
# 541675    581538     22068       BLACK PIRATE TREASURE CHEST       1.0
# 541689    581538     23318    BOX OF 6 MINI VINTAGE CRACKERS       1.0
# 541692    581538     22992            REVOLVER WOODEN RULER        1.0
# 541699    581538     22694                      WICKER STAR        1.0
# 541701    581538     23343      JUMBO BAG VINTAGE CHRISTMAS        1.0
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
(
  df
  .groupby(df.columns.tolist(), dropna=False)
  .size()
  .to_frame('n_duplicates')
  .query('n_duplicates>1')
  .sort_values('n_duplicates',ascending=False)
  .head(5)



)
# Out:
#                                                                                                                        n_duplicates
# InvoiceNo StockCode Description                         Quantity InvoiceDate      UnitPrice CustomerID Country
# 555524    22698     PINK REGENCY TEACUP AND SAUCER      1.0      6/5/2011 11:37   2.95      16923.0    United Kingdom            20
#           22697     GREEN REGENCY TEACUP AND SAUCER     1.0      6/5/2011 11:37   2.95      16923.0    United Kingdom            12
# 572861    22775     PURPLE DRAWERKNOB ACRYLIC EDWARDIAN 12.0     10/26/2011 12:46 1.25      14102.0    United Kingdom             8
# 541266    21755     LOVE BUILDING BLOCK WORD            1.0      1/16/2011 16:25  5.95      15673.0    United Kingdom             6
# 572344    M         Manual                              48.0     10/24/2011 10:43 1.50      14607.0    United Kingdom             6

# %%
df.isna()
# Out:
#         InvoiceNo  StockCode  Description  Quantity  InvoiceDate  UnitPrice  \
# 0           False      False        False     False        False      False
# 1           False      False        False     False        False      False
# 2           False      False        False     False        False      False
# 3           False      False        False     False        False      False
# 4           False      False        False     False        False      False
# ...           ...        ...          ...       ...          ...        ...
# 541904      False      False        False     False        False      False
# 541905      False      False        False     False        False      False
# 541906      False      False        False     False        False      False
# 541907      False      False        False     False        False      False
# 541908      False      False        False     False        False      False
#
#         CustomerID  Country
# ...

# %%
df.isna().sum()
# Out:
# InvoiceNo           0
# StockCode        6035
# Description      7489
# Quantity         6035
# InvoiceDate      6035
# UnitPrice        6035
# CustomerID     138727
# Country          6035
# dtype: int64

# %%
df.isna().sum() / df.shape[0] * 100
# Out:
# InvoiceNo       0.000000
# StockCode       1.113656
# Description     1.381966
# Quantity        1.113656
# InvoiceDate     1.113656
# UnitPrice       1.113656
# CustomerID     25.599686
# Country         1.113656
# dtype: float64

# %%
df.isna().sum().to_frame('missing_count')
# Out:
#              missing_count
# InvoiceNo                0
# StockCode             6035
# Description           7489
# Quantity              6035
# InvoiceDate           6035
# UnitPrice             6035
# CustomerID          138727
# Country               6035

# %%
df_missing = (

 df.isna().sum()
 .to_frame('missing_count')
 .join((df.isna().sum() / df.shape[0]).to_frame('missing_pct'))
 .sort_values('missing_count' , ascending=False)

)
df_missing
# Out:
#              missing_count  missing_pct
# CustomerID          138727     0.255997
# Description           7489     0.013820
# StockCode             6035     0.011137
# Quantity              6035     0.011137
# InvoiceDate           6035     0.011137
# UnitPrice             6035     0.011137
# Country               6035     0.011137
# InvoiceNo                0     0.000000

# %%
df_missing
# Out:
#              missing_count  missing_pct
# CustomerID          138727     0.255997
# Description           7489     0.013820
# StockCode             6035     0.011137
# Quantity              6035     0.011137
# InvoiceDate           6035     0.011137
# UnitPrice             6035     0.011137
# Country               6035     0.011137
# InvoiceNo                0     0.000000

# %%
df.isna().sum().to_frame('missing_count').assign(missing_pct= lambda x: x.div(len(df))).sort_values('missing_count' , ascending=False)
# Out:
#              missing_count  missing_pct
# CustomerID          138727     0.255997
# Description           7489     0.013820
# StockCode             6035     0.011137
# Quantity              6035     0.011137
# InvoiceDate           6035     0.011137
# UnitPrice             6035     0.011137
# Country               6035     0.011137
# InvoiceNo                0     0.000000

# %%
df.isna().any()
# Out:
# InvoiceNo      False
# StockCode       True
# Description     True
# Quantity        True
# InvoiceDate     True
# UnitPrice       True
# CustomerID      True
# Country         True
# dtype: bool

# %%
df[df.Country.isna()]
# Out:
#                                                 InvoiceNo StockCode  \
# 109     536381,82567,"AIRLINE LOUNGE,METAL SIGN",2,12/...       NaN
# 253     536394,21506,"FANCY FONT BIRTHDAY CARD, ",24,1...       NaN
# 871     536477,22041,"RECORD FRAME 7"" SINGLE SIZE ",4...       NaN
# 956     536520,22760,"TRAY, BREAKFAST IN BED",1,12/1/2...       NaN
# 1014    536520,21111,"SWISS ROLL TOWEL, CHOCOLATE  SPO...       NaN
# ...                                                   ...       ...
# 541379  581498,22041,"RECORD FRAME 7"" SINGLE SIZE ",2...       NaN
# 541549  581501,22165,"DIAMANTE HEART SHAPED WALL MIRRO...       NaN
# 541614  581516,21111,"SWISS ROLL TOWEL, CHOCOLATE  SPO...       NaN
# 541649  581538,85071C,"CHARLIE+LOLA""EXTREMELY BUSY"" ...       NaN
# 541787  581578,21506,"FANCY FONT BIRTHDAY CARD, ",12,1...       NaN
#
#        Description  Quantity InvoiceDate  UnitPrice  CustomerID Country
# 109            NaN       NaN         NaN        NaN         NaN     NaN
# ...

# %%
df = df.dropna(subset=['CustomerID'])

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1         536365     71053                  WHITE METAL LANTERN       6.0
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS      12.0
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL        6.0
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL        4.0
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE       4.0
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT        3.0
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.isna().any()
# Out:
# InvoiceNo      False
# StockCode      False
# Description    False
# Quantity       False
# InvoiceDate    False
# UnitPrice      False
# CustomerID     False
# Country        False
# dtype: bool

# %%
df[df.UnitPrice.isna()]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
df_q = df.query("UnitPrice<0")

# %%
df_q.head()
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
df_q
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
df_1 = df.drop(df[df['UnitPrice'] < 0].index)

# %%
df_1.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1    536365     71053                  WHITE METAL LANTERN       6.0
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df_1
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1         536365     71053                  WHITE METAL LANTERN       6.0
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS      12.0
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL        6.0
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL        4.0
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE       4.0
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT        3.0
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df_q2 = df_1.query("Quantity<0")

# %%
df_q2
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount      -1.0
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS      -1.0
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE      -12.0
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES      -24.0
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES      -24.0
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL     -11.0
# 541541   C581499         M                            Manual      -1.0
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE      -5.0
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER      -1.0
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT      -5.0
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df_2 = df_1.drop(df_1[df_1['Quantity'] < 0].index)

# %%
df_2.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1    536365     71053                  WHITE METAL LANTERN       6.0
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df_2
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1         536365     71053                  WHITE METAL LANTERN       6.0
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS      12.0
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL        6.0
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL        4.0
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE       4.0
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT        3.0
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df_2.duplicated().sum()
# Out:
# 5147

# %%
df_2.duplicated(keep=False).sum()
# Out:
# 9913

# %%
(
  df_2
  .groupby(df.columns.tolist(), dropna=False)
  .size()
  .to_frame('n_duplicates')
  .query('n_duplicates>1')
  .sort_values('n_duplicates',ascending=False)
  .head(5)



)
# Out:
#                                                                                                                        n_duplicates
# InvoiceNo StockCode Description                         Quantity InvoiceDate      UnitPrice CustomerID Country
# 555524    22698     PINK REGENCY TEACUP AND SAUCER      1.0      6/5/2011 11:37   2.95      16923.0    United Kingdom            20
#           22697     GREEN REGENCY TEACUP AND SAUCER     1.0      6/5/2011 11:37   2.95      16923.0    United Kingdom            12
# 572861    22775     PURPLE DRAWERKNOB ACRYLIC EDWARDIAN 12.0     10/26/2011 12:46 1.25      14102.0    United Kingdom             8
# 572344    M         Manual                              48.0     10/24/2011 10:43 1.50      14607.0    United Kingdom             6
# 541266    21755     LOVE BUILDING BLOCK WORD            1.0      1/16/2011 16:25  5.95      15673.0    United Kingdom             6

# %%
df_3 = df_2.drop_duplicates()

# %%
df_3
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1         536365     71053                  WHITE METAL LANTERN       6.0
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS      12.0
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL        6.0
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL        4.0
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE       4.0
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT        3.0
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df_3 = df_3.astype({"CustomerID":"int"})

# %%
df_3.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity       float64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID       int64
# Country         object
# dtype: object

# %%
df_3.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity       float64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID       int64
# Country         object
# dtype: object

# %%
df_3['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# %%
df_3.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity              float64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID              int64
# Country                object
# dtype: object

# %%
df_3 = df_3.astype({"Quantity":"int"})

# %%
df_3
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df_3.plot.box()
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import scale

# %%
df_3.describe()
# Out:
#             Quantity                    InvoiceDate      UnitPrice  \
# count  389196.000000                         389196  389196.000000
# mean       12.925580  2011-07-10 23:53:29.084265984       3.137815
# min         1.000000            2010-12-01 08:26:00       0.000000
# 25%         2.000000            2011-04-07 12:00:00       1.250000
# 50%         6.000000            2011-07-31 14:17:00       1.950000
# 75%        12.000000            2011-10-20 13:07:00       3.750000
# max     74215.000000            2011-12-09 12:50:00    8142.750000
# std       128.071315                            NaN      22.339928
#
#           CustomerID
# count  389196.000000
# mean    15287.782786
# min     12346.000000
# 25%     13954.000000
# 50%     15152.000000
# 75%     16791.000000
# max     18287.000000
# std      1714.020387

# %%
Outliers = (df_3['Quantity'] > 10000) & (df_3['UnitPrice'] > 5000)

# %%
df_4 = df_3.drop(df_3[Outliers].index)

# %%
df_4
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
preco_total = (df_4['Quantity'] * df_4['UnitPrice'])

# %%
df_4['preco_total'] = (df_4['Quantity'] * df_4['UnitPrice'])

# %%
df_4.max()
# Out:
# InvoiceNo                                581587
# StockCode                                  POST
# Description    ZINC WIRE SWEETHEART LETTER TRAY
# Quantity                                  74215
# InvoiceDate                 2011-12-09 12:50:00
# UnitPrice                               8142.75
# CustomerID                                18287
# Country                             Unspecified
# preco_total                             77183.6
# dtype: object

# %%
df_5 = df_4.groupby(["Country"])["preco_total"].sum().reset_index()

# %%
df_5
# Out:
#                  Country  preco_total
# 0              Australia   136670.250
# 1                Austria    10178.340
# 2                Bahrain      548.400
# 3                Belgium    41014.360
# 4                 Brazil     1143.600
# 5                 Canada     3599.680
# 6        Channel Islands    20300.540
# 7                 Cyprus    13347.870
# 8         Czech Republic      826.740
# 9                Denmark    18852.380
# 10                  EIRE   263656.760
# 11    European Community     1300.250
# 12               Finland    22441.080
# 13                France   208600.960
# 14               Germany   227721.970
# 15                Greece     4694.820
# 16               Iceland     4299.800
# 17                Israel     7175.440
# 18                 Italy    17098.760
# 19                 Japan    36691.810
# 20               Lebanon     1693.880
# 21             Lithuania     1661.060
# 22                 Malta     2723.310
# 23           Netherlands   284023.860
# ...

# %%
df_ordenado = df_5.sort_values('preco_total', ascending=False)

# %%
df_ordenado
# Out:
#                  Country  preco_total
# 35        United Kingdom  7072197.314
# 23           Netherlands   284023.860
# 10                  EIRE   263656.760
# 14               Germany   227721.970
# 13                France   208600.960
# 0              Australia   136670.250
# 30                 Spain    61401.240
# 32           Switzerland    56222.430
# 3                Belgium    41014.360
# 31                Sweden    38146.070
# 19                 Japan    36691.810
# 24                Norway    35908.160
# 26              Portugal    33281.160
# 12               Finland    22441.080
# 29             Singapore    21213.590
# 6        Channel Islands    20300.540
# 9                Denmark    18852.380
# 18                 Italy    17098.760
# 7                 Cyprus    13347.870
# 1                Austria    10178.340
# 25                Poland     7314.850
# 17                Israel     7175.440
# 15                Greece     4694.820
# 16               Iceland     4299.800
# ...

# %%
df_10_primeiros_1 = df_ordenado.head(10)

# %%
df_10_primeiros_1
# Out:
#            Country  preco_total
# 35  United Kingdom  7072197.314
# 23     Netherlands   284023.860
# 10            EIRE   263656.760
# 14         Germany   227721.970
# 13          France   208600.960
# 0        Australia   136670.250
# 30           Spain    61401.240
# 32     Switzerland    56222.430
# 3          Belgium    41014.360
# 31          Sweden    38146.070

# %%
plt.figure(figsize=(10, 8))
plt.bar(df_10_primeiros_1['Country'], df_10_primeiros_1['preco_total'])
plt.xlabel('País')
plt.ylabel('Valor de Vendas')
plt.title('Top 10 Países com Maior Valor de Vendas')
plt.xticks(rotation=60, ha='right')
plt.show()

# %%
df_6 = df_4.groupby(["Description"])["Quantity"].sum().reset_index()

# %%
df_6
# Out:
#                            Description  Quantity
# 0        4 PURPLE FLOCK DINNER CANDLES       138
# 1        50'S CHRISTMAS GIFT BAG LARGE      1885
# 2                    DOLLY GIRL BEAKER      2394
# 3          I LOVE LONDON MINI BACKPACK       359
# 4          I LOVE LONDON MINI RUCKSACK         1
# ...                                ...       ...
# 3768   ZINC T-LIGHT HOLDER STARS SMALL      4894
# 3769    ZINC TOP  2 DOOR WOODEN SHELF         10
# 3770  ZINC WILLIE WINKIE  CANDLE STICK      2606
# 3771       ZINC WIRE KITCHEN ORGANISER        25
# 3772  ZINC WIRE SWEETHEART LETTER TRAY        80
#
# [3773 rows x 2 columns]

# %%
df_ordenado_6 = df_6.sort_values('Quantity', ascending=False)

# %%
df_ordenado_6
# Out:
#                               Description  Quantity
# 1919       MEDIUM CERAMIC TOP STORAGE JAR     77916
# 3684    WORLD WAR 2 GLIDERS ASSTD DESIGNS     54319
# 1718              JUMBO BAG RED RETROSPOT     46078
# 3597   WHITE HANGING HEART T-LIGHT HOLDER     36706
# 207         ASSORTED COLOUR BIRD ORNAMENT     35263
# ...                                   ...       ...
# 853        CROCHET LILAC/RED BEAR KEYRING         1
# 852                   CROCHET DOG KEYRING         1
# 3028  SET/3 TALL GLASS CANDLE HOLDER PINK         1
# 3021     SET/3 FLORAL GARDEN TOOLS IN BAG         1
# 2826              SCALLOP SHELL SOAP DISH         1
#
# [3773 rows x 2 columns]

# %%
df_10_primeiros_6 = df_ordenado_6.head(10)

# %%
df_10_primeiros_6
# Out:
#                              Description  Quantity
# 1919      MEDIUM CERAMIC TOP STORAGE JAR     77916
# 3684   WORLD WAR 2 GLIDERS ASSTD DESIGNS     54319
# 1718             JUMBO BAG RED RETROSPOT     46078
# 3597  WHITE HANGING HEART T-LIGHT HOLDER     36706
# 207        ASSORTED COLOUR BIRD ORNAMENT     35263
# 2194     PACK OF 72 RETROSPOT CAKE CASES     33670
# 2519                      POPCORN HOLDER     30919
# 2575                  RABBIT NIGHT LIGHT     27153
# 1973             MINI PAINT SET VINTAGE      26076
# 2160          PACK OF 12 LONDON TISSUES      25329

# %%
plt.figure(figsize=(10, 8))
plt.bar(df_10_primeiros_6['Description'], df_10_primeiros_6['Quantity'])
plt.xlabel('Produto')
plt.ylabel('Quantidade')
plt.title('Top 10 Produtos mais vendidos')
plt.xticks(rotation=60, ha='right')
plt.show()

# %%
df_7 = df_4.groupby(["InvoiceDate"])["preco_total"].sum().reset_index()

# %%
df_7
# Out:
#               InvoiceDate  preco_total
# 0     2010-12-01 08:26:00       139.12
# 1     2010-12-01 08:28:00        22.20
# 2     2010-12-01 08:34:00       348.78
# 3     2010-12-01 08:35:00        17.85
# 4     2010-12-01 08:45:00       855.86
# ...                   ...          ...
# 17271 2011-12-09 12:23:00       124.60
# 17272 2011-12-09 12:25:00       140.64
# 17273 2011-12-09 12:31:00       329.05
# 17274 2011-12-09 12:49:00       339.20
# 17275 2011-12-09 12:50:00       249.45
#
# [17276 rows x 2 columns]

# %%
df_4
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  preco_total
# ...

# %%
#df_7 = df_4.groupby(["InvoiceDate"].dt.month)["preco_total"].sum().reset_index()

# %%
dados_por_mes = df_4.groupby(pd.Grouper(key='InvoiceDate', freq='M'))

# %%
total_vendas_por_mes = dados_por_mes['preco_total'].sum()

# %%
total_vendas_por_mes.reset_index()
# Out:
#    InvoiceDate  preco_total
# 0   2010-12-31   565772.820
# 1   2011-01-31   563553.660
# 2   2011-02-28   441599.640
# 3   2011-03-31   589909.980
# 4   2011-04-30   464122.541
# 5   2011-05-31   672249.700
# 6   2011-06-30   655950.120
# 7   2011-07-31   595188.911
# 8   2011-08-31   641124.600
# 9   2011-09-30   945995.612
# 10  2011-10-31  1032005.980
# 11  2011-11-30  1151187.530
# 12  2011-12-31   346552.970

# %%
total_vendas_1 = total_vendas_por_mes.reset_index()

# %%
total_vendas_por_mes
# Out:
# InvoiceDate
# 2010-12-31     565772.820
# 2011-01-31     563553.660
# 2011-02-28     441599.640
# 2011-03-31     589909.980
# 2011-04-30     464122.541
# 2011-05-31     672249.700
# 2011-06-30     655950.120
# 2011-07-31     595188.911
# 2011-08-31     641124.600
# 2011-09-30     945995.612
# 2011-10-31    1032005.980
# 2011-11-30    1151187.530
# 2011-12-31     346552.970
# Freq: M, Name: preco_total, dtype: float64

# %%
total_vendas_1
# Out:
#    InvoiceDate  preco_total
# 0   2010-12-31   565772.820
# 1   2011-01-31   563553.660
# 2   2011-02-28   441599.640
# 3   2011-03-31   589909.980
# 4   2011-04-30   464122.541
# 5   2011-05-31   672249.700
# 6   2011-06-30   655950.120
# 7   2011-07-31   595188.911
# 8   2011-08-31   641124.600
# 9   2011-09-30   945995.612
# 10  2011-10-31  1032005.980
# 11  2011-11-30  1151187.530
# 12  2011-12-31   346552.970

# %%
plt.figure(figsize=(10, 8))
plt.bar(total_vendas_1['InvoiceDate'], total_vendas_1['preco_total'], width=3.0)
plt.xlabel('Mes')
plt.ylabel('Vendas')
plt.title('Vendas por mes')
plt.xticks(rotation=60, ha='right')
plt.show()

# %%
df_4.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID              int64
# Country                object
# preco_total           float64
# dtype: object

# %%
#df_5 = df_4.groupby(["Country"])["preco_total"].sum().reset_index()

# %%
df_mes_pais = pd.DataFrame({
              'InvoiceDate':['2011-01-31','2011-02-28','2011-03-31', '2011-04-30','2011-05-31	','	2011-06-30', '2011-07-31', '2011-08-31', '2011-09-30','2011-10-31'],
              'Country':['United Kingdom', 'Netherlands','EIRE', 'Germany', 'France', 'Australia', 'Spain', 'Switzerland', 'Belgium', 'Sweden	'],
              'preco_total':[7072197 , 284023, 263656, 227721, 208600, 136670, 61401, 56222, 41014, 38146]


})

# %%
df_mes_pais_ordenado = df_mes_pais.sort_values('preco_total', ascending=False)

# %%
df_4_grup = df_4.groupby(["Country"])["preco_total"].sum().reset_index()

# %%
plt.figure(figsize=(10, 8))
plt.bar(df_10_primeiros_1['Country'], df_10_primeiros_1['preco_total'])
plt.xlabel('País')
plt.ylabel('Valor de Vendas')
plt.title('Top 10 Países com Maior Valor de Vendas')
plt.xticks(rotation=60, ha='right')
plt.show()

# %%
df_10_primeiros_1
# Out:
#            Country  preco_total
# 35  United Kingdom  7072197.314
# 23     Netherlands   284023.860
# 10            EIRE   263656.760
# 14         Germany   227721.970
# 13          France   208600.960
# 0        Australia   136670.250
# 30           Spain    61401.240
# 32     Switzerland    56222.430
# 3          Belgium    41014.360
# 31          Sweden    38146.070

# %%
df_4
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  preco_total
# ...

# %%
dados_janeiro = df_4[(df_4['InvoiceDate'].dt.month == 1) & (df_4['InvoiceDate'].dt.year==2011)]

# %%
total_vendas_por_pais = dados_janeiro.groupby(['Country'])['preco_total'].sum()

# %%
display(total_vendas_por_pais)
# Out:
# Country
# Australia            9007.51
# Belgium              1200.20
# Channel Islands       675.58
# Cyprus                530.70
# EIRE                21878.15
# Finland               889.02
# France              17707.18
# Germany             16712.90
# Greece               2595.54
# Iceland               475.39
# Italy                2402.51
# Lebanon              1693.88
# Netherlands         26257.88
# Poland                613.22
# Portugal             4055.71
# Singapore            1987.37
# Spain               10051.23
# Sweden               3486.32
# Switzerland          4212.75
# United Kingdom     437120.62
# Name: preco_total, dtype: float64

# %%
total_vendas_por_pais.reset_index()
# Out:
#             Country  preco_total
# 0         Australia      9007.51
# 1           Belgium      1200.20
# 2   Channel Islands       675.58
# 3            Cyprus       530.70
# 4              EIRE     21878.15
# 5           Finland       889.02
# 6            France     17707.18
# 7           Germany     16712.90
# 8            Greece      2595.54
# 9           Iceland       475.39
# 10            Italy      2402.51
# 11          Lebanon      1693.88
# 12      Netherlands     26257.88
# 13           Poland       613.22
# 14         Portugal      4055.71
# 15        Singapore      1987.37
# 16            Spain     10051.23
# 17           Sweden      3486.32
# 18      Switzerland      4212.75
# 19   United Kingdom    437120.62

# %%
total_vendas_por_pais_ordenado = total_vendas_por_pais.sort_values(ascending=False)

# %%
total_vendas_por_pais_ordenado.reset_index()
# Out:
#             Country  preco_total
# 0    United Kingdom    437120.62
# 1       Netherlands     26257.88
# 2              EIRE     21878.15
# 3            France     17707.18
# 4           Germany     16712.90
# 5             Spain     10051.23
# 6         Australia      9007.51
# 7       Switzerland      4212.75
# 8          Portugal      4055.71
# 9            Sweden      3486.32
# 10           Greece      2595.54
# 11            Italy      2402.51
# 12        Singapore      1987.37
# 13          Lebanon      1693.88
# 14          Belgium      1200.20
# 15          Finland       889.02
# 16  Channel Islands       675.58
# 17           Poland       613.22
# 18           Cyprus       530.70
# 19          Iceland       475.39

# %%
total_vendas_por_pais_ordenado_1 = total_vendas_por_pais_ordenado.head(10)

# %%
total_vendas_por_pais_ordenado_1.reset_index()
# Out:
#           Country  preco_total
# 0  United Kingdom    437120.62
# 1     Netherlands     26257.88
# 2            EIRE     21878.15
# 3          France     17707.18
# 4         Germany     16712.90
# 5           Spain     10051.23
# 6       Australia      9007.51
# 7     Switzerland      4212.75
# 8        Portugal      4055.71
# 9          Sweden      3486.32

# %%
total_vendas_por_pais_ordenado_1 = total_vendas_por_pais_ordenado_1.reset_index()

# %%
total_vendas_por_pais_ordenado_1
# Out:
#           Country  preco_total
# 0  United Kingdom    437120.62
# 1     Netherlands     26257.88
# 2            EIRE     21878.15
# 3          France     17707.18
# 4         Germany     16712.90
# 5           Spain     10051.23
# 6       Australia      9007.51
# 7     Switzerland      4212.75
# 8        Portugal      4055.71
# 9          Sweden      3486.32

# %%
#print(df_total_vendas_por_pais_ordenado_1.columns)

# %%
total_vendas_por_pais_ordenado_1.columns = total_vendas_por_pais_ordenado_1.columns.str.strip()

# %%
print(total_vendas_por_pais_ordenado_1.head())
# Out:
#           Country  preco_total
# 0  United Kingdom    437120.62
# 1     Netherlands     26257.88
# 2            EIRE     21878.15
# 3          France     17707.18
# 4         Germany     16712.90

# %%
plt.figure(figsize=(10, 8))
plt.bar(total_vendas_por_pais_ordenado_1['Country'], total_vendas_por_pais_ordenado_1['preco_total'])
plt.xlabel('País')
plt.ylabel('Valor de Vendas em janeiro')
plt.title('Top 10 Países com Maior Valor de Vendas em janeiro')
plt.xticks(rotation=60, ha='right')
plt.show()

# %%
#df_6 = df_4.groupby(["Description"])["Quantity"].sum().reset_index()

# %%
df_4
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  preco_total
# ...

# %%
df_pedido = df_4.groupby(["InvoiceNo"])["preco_total"].sum()

# %%
df_pedido.reset_index()
# Out:
#       InvoiceNo  preco_total
# 0        536365       139.12
# 1        536366        22.20
# 2        536367       278.73
# 3        536368        70.05
# 4        536369        17.85
# ...         ...          ...
# 18520    581583       124.60
# 18521    581584       140.64
# 18522    581585       329.05
# 18523    581586       339.20
# 18524    581587       249.45
#
# [18525 rows x 2 columns]

# %%
df_pedido_mean = df_4.groupby(["InvoiceNo"])["preco_total"].mean()

# %%
df_pedido_mean.reset_index()
# Out:
#       InvoiceNo  preco_total
# 0        536365    19.874286
# 1        536366    11.100000
# 2        536367    23.227500
# 3        536368    17.512500
# 4        536369    17.850000
# ...         ...          ...
# 18520    581583    62.300000
# 18521    581584    70.320000
# 18522    581585    15.669048
# 18523    581586    84.800000
# 18524    581587    16.630000
#
# [18525 rows x 2 columns]

# %%
df_4
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  preco_total
# ...

# %%
df_pedido_frequencia = df_4.groupby(["InvoiceNo"])["Quantity"].sum()

# %%
df_pedido_frequencia.reset_index()
# Out:
#       InvoiceNo  Quantity
# 0        536365        40
# 1        536366        12
# 2        536367        83
# 3        536368        15
# 4        536369         3
# ...         ...       ...
# 18520    581583        76
# 18521    581584       120
# 18522    581585       278
# 18523    581586        66
# 18524    581587       105
#
# [18525 rows x 2 columns]
